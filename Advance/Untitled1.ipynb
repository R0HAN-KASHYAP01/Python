# %%
import numpy as np
import pandas as pd

# %%
dict1 = {"Name" : ["Rohan","uday",'Atul','Dipesh'],
        'marks' : [94,92,85,97]}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#      Name  marks
# 0   Rohan     94
# 1    uday     92
# 2    Atul     85
# 3  Dipesh     97

# %%
df.to_csv('Friends.csv')

# %%
df.to_csv('friends_index_false.csv',index = False)

# %%
# ?df.to_csv('friends_index_false.csv',index = False)
# Out:
# Object `df.to_csv('friends_index_false.csv',index = False)` not found.

# %%
df.to_csv('friends_index_false.csv',index = False)

# %%
df.head(2)
# Out:
#     Name  marks
# 0  Rohan     94
# 1   uday     92

# %%
df.head()
# Out:
#      Name  marks
# 0   Rohan     94
# 1    uday     92
# 2    Atul     85
# 3  Dipesh     97

# %%
df.tail()
# Out:
#      Name  marks
# 0   Rohan     94
# 1    uday     92
# 2    Atul     85
# 3  Dipesh     97

# %%
df.tail(2)
# Out:
#      Name  marks
# 2    Atul     85
# 3  Dipesh     97

# %%
df.describe()
# Out:
#           marks
# count   4.00000
# mean   92.00000
# std     5.09902
# min    85.00000
# 25%    90.25000
# 50%    93.00000
# 75%    94.75000
# max    97.00000

# %%
pd.to_read('hello.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 pd.to_read('hello.csv')
#
# AttributeError: module 'pandas' has no attribute 'to_read'

# %%
data = pd.read_csv('hello.csv')

# %%
data
# Out:
#      Name  marks
# 0   Rohan     94
# 1    uday     92
# 2    Atul     85
# 3  Dipesh     97

# %%
data
# Out:
#      Name  marks
# 0   Rohan     94
# 1    uday     92
# 2    Atul     85
# 3  Dipesh     97

# %%
data = pd.read_csv('hello.csv')

# %%
data
# Out:
#    Train  Speed
# 0    122     94
# 1    123     92
# 2    124     85
# 3    125     97

# %%
data['Speed']
# Out:
# 0    94
# 1    92
# 2    85
# 3    97
# Name: Speed, dtype: int64

# %%
data['Speed'][2]
# Out:
# 85

# %%
data['Speed'][2] = 90

# %%
data
# Out:
#    Train  Speed
# 0    122     94
# 1    123     92
# 2    124     90
# 3    125     97

# %%
data.to_csv('hello.csv')

# %%
dict1.to_csv('hello.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 dict1.to_csv('hello.csv')
#
# AttributeError: 'dict' object has no attribute 'to_csv'

# %%
data.to_csv('Friends')

# %%
data
# Out:
#    Train  Speed
# 0    122     94
# 1    123     92
# 2    124     90
# 3    125     97

# %%
indexing = [1,2,3,4]

# %%
data.index('indexing')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 data.index('indexing')
#
# TypeError: 'RangeIndex' object is not callable

# %%
data.index = [1,2,3,4]

# %%
data
# Out:
#    Train  Speed
# 1    122     94
# 2    123     92
# 3    124     90
# 4    125     97

# %%
dict2 = {1:['A'],
         2:['B'],
         3:['C'],
         4:['D']}

# %%
dict2
# Out:
# {1: 'A', 2: 'B', 3: 'C', 4: 'D'}

# %%
df = pd.DataFrame(dict2)

# %%
df = pd.DataFrame(dict1)

# %%
df = pd.DataFrame(dict2)

# %%
df
# Out:
#    1  2  3  4
# 0  A  B  C  D

# %%
df.to_csv('numbers.csv')

# %%
newdf = pd.DataFrame(np.random.rand(344,5))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.392648  0.709635  0.226544  0.667087  0.961524
# 1    0.966325  0.022457  0.341397  0.462687  0.792074
# 2    0.217430  0.325960  0.572147  0.600758  0.015973
# 3    0.704062  0.103476  0.721498  0.828908  0.567209
# 4    0.992961  0.834203  0.128913  0.611308  0.837718
# ..        ...       ...       ...       ...       ...
# 339  0.444353  0.319412  0.829144  0.450701  0.249373
# 340  0.969520  0.180191  0.925243  0.054374  0.285382
# 341  0.651217  0.645574  0.488367  0.484925  0.714517
# 342  0.016924  0.595805  0.917221  0.351070  0.483793
# 343  0.775888  0.106898  0.794564  0.347281  0.614387
#
# [344 rows x 5 columns]

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.392648  0.709635  0.226544  0.667087  0.961524
# 1  0.966325  0.022457  0.341397  0.462687  0.792074
# 2  0.217430  0.325960  0.572147  0.600758  0.015973
# 3  0.704062  0.103476  0.721498  0.828908  0.567209
# 4  0.992961  0.834203  0.128913  0.611308  0.837718

# %%
newdf.tail()
# Out:
#             0         1         2         3         4
# 339  0.444353  0.319412  0.829144  0.450701  0.249373
# 340  0.969520  0.180191  0.925243  0.054374  0.285382
# 341  0.651217  0.645574  0.488367  0.484925  0.714517
# 342  0.016924  0.595805  0.917221  0.351070  0.483793
# 343  0.775888  0.106898  0.794564  0.347281  0.614387

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.392648  0.709635  0.226544  0.667087  0.961524
# 1  0.966325  0.022457  0.341397  0.462687  0.792074
# 2  0.217430  0.325960  0.572147  0.600758  0.015973
# 3  0.704062  0.103476  0.721498  0.828908  0.567209
# 4  0.992961  0.834203  0.128913  0.611308  0.837718

# %%
newdf.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 newdf.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf[0][1]
# Out:
# 0.9663254832207733

# %%
newdf[0][1] = 'Uday'
# Out:
# C:\Users\Rohan\AppData\Local\Temp\ipykernel_13440\2269656533.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newdf[0
0.572147  0.600758  0.015973
# 3    0.704062  0.103476  0.721498  0.828908  0.567209
# 4    0.992961  0.834203  0.128913  0.611308  0.837718
# ..        ...       ...       ...       ...       ...
# 339  0.444353  0.319412  0.829144  0.450701  0.249373
# 340   0.96952  0.180191  0.925243  0.054374  0.285382
# 341  0.651217  0.645574  0.488367  0.484925  0.714517
# 342  0.016924  0.595805  0.917221  0.351070  0.483793
# 343  0.775888  0.106898  0.794564  0.347281  0.614387
#
# [344 rows x 5 columns]

# %%
newdf2.head()
# Out:
#           0         1         2         3         4
# 0  0.392648  0.709635  0.226544  0.667087  0.961524
# 1      Uday  0.022457  0.341397  0.462687  0.792074
# 2   0.21743  0.325960  0.572147  0.600758  0.015973
# 3  0.704062  0.103476  0.721498  0.828908  0.567209
# 4  0.992961  0.834203  0.128913  0.611308  0.837718

# %%
newdf2[1][0] = 'ROhan'
# Out:
# C:\Users\Rohan\AppData\Local\Temp\ipykernel_13440\2302321617.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newdf2[1][0] = 'ROhan'
# ...

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.392648     ROhan  0.226544  0.667087  0.961524
# 1        Uday  0.022457  0.341397  0.462687  0.792074
# 2     0.21743   0.32596  0.572147  0.600758  0.015973
# 3    0.704062  0.103476  0.721498  0.828908  0.567209
# 4    0.992961  0.834203  0.128913  0.611308  0.837718
# ..        ...       ...       ...       ...       ...
# 339  0.444353  0.319412  0.829144  0.450701  0.249373
# 340   0.96952  0.180191  0.925243  0.054374  0.285382
# 341  0.651217  0.645574  0.488367  0.484925  0.714517
# 342  0.016924  0.595805  0.917221  0.351070  0.483793
# 343  0.775888  0.106898  0.794564  0.347281  0.614387
#
# [344 rows x 5 columns]

# %%
newdf2
# Out:
#             0         1         2         3         4
# 0    0.392648     ROhan  0.226544  0.667087  0.961524
# 1        Uday  0.022457  0.341397  0.462687  0.792074
# 2     0.21743   0.32596  0.572147  0.600758  0.015973
# 3    0.704062  0.103476  0.721498  0.828908  0.567209
# 4    0.992961  0.834203  0.128913  0.611308  0.837718
# ..        ...       ...       ...       ...       ...
# 339  0.444353  0.319412  0.829144  0.450701  0.249373
# 340   0.96952  0.180191  0.925243  0.054374  0.285382
# 341  0.651217  0.645574  0.488367  0.484925  0.714517
# 342  0.016924  0.595805  0.917221  0.351070  0.483793
# 343  0.775888  0.106898  0.794564  0.347281  0.614387
#
# [344 rows x 5 columns]

# %%
newdf2 = newdf.copy()

# %%
newdf2[0][0] = 'Atul'
# Out:
# C:\Users\Rohan\AppData\Local\Temp\ipykernel_13440\4176538944.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newdf2[0][0] = 'Atul'
# ...

# %%
newdf2
# Out:
#             0         1         2         3         4
# 0        Atul     ROhan  0.226544  0.667087  0.961524
# 1        Uday  0.022457  0.341397  0.462687  0.792074
# 2     0.21743   0.32596  0.572147  0.600758  0.015973
# 3    0.704062  0.103476  0.721498  0.828908  0.567209
# 4    0.992961  0.834203  0.128913  0.611308  0.837718
# ..        ...       ...       ...       ...       ...
# 339  0.444353  0.319412  0.829144  0.450701  0.249373
# 340   0.96952  0.180191  0.925243  0.054374  0.285382
# 341  0.651217  0.645574  0.488367  0.484925  0.714517
# 342  0.016924  0.595805  0.917221  0.351070  0.483793
# 343  0.775888  0.106898  0.794564  0.347281  0.614387
#
# [344 rows x 5 columns]

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.392648     ROhan  0.226544  0.667087  0.961524
# 1      Uday  0.022457  0.341397  0.462687  0.792074
# 2   0.21743   0.32596  0.572147  0.600758  0.015973
# 3  0.704062  0.103476  0.721498  0.828908  0.567209
# 4  0.992961  0.834203  0.128913  0.611308  0.837718

# %%
newdf2 = newdf[:]

# %%
newdf2[1][1] = 'Dipesh'
# Out:
# C:\Users\Rohan\AppData\Local\Temp\ipykernel_13440\957408258.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newdf2[1][1] = 'Dipesh'
# ...

# %%
newdf2.head()
# Out:
#           0         1         2         3         4
# 0  0.392648     ROhan  0.226544  0.667087  0.961524
# 1      Uday    Dipesh  0.341397  0.462687  0.792074
# 2   0.21743   0.32596  0.572147  0.600758  0.015973
# 3  0.704062  0.103476  0.721498  0.828908  0.567209
# 4  0.992961  0.834203  0.128913  0.611308  0.837718

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.392648     ROhan  0.226544  0.667087  0.961524
# 1      Uday    Dipesh  0.341397  0.462687  0.792074
# 2   0.21743   0.32596  0.572147  0.600758  0.015973
# 3  0.704062  0.103476  0.721498  0.828908  0.567209
# 4  0.992961  0.834203  0.128913  0.611308  0.837718

# %%
newdf.loc[]
# Out:
#   Cell In[63], line 1
#     newdf.loc[]
#               ^
# SyntaxError: invalid syntax

# %%
newdf.loc[:]
# Out:
#             0         1         2         3         4
# 0    0.392648     ROhan  0.226544  0.667087  0.961524
# 1        Uday    Dipesh  0.341397  0.462687  0.792074
# 2     0.21743   0.32596  0.572147  0.600758  0.015973
# 3    0.704062  0.103476  0.721498  0.828908  0.567209
# 4    0.992961  0.834203  0.128913  0.611308  0.837718
# ..        ...       ...       ...       ...       ...
# 339  0.444353  0.319412  0.829144  0.450701  0.249373
# 340   0.96952  0.180191  0.925243  0.054374  0.285382
# 341  0.651217  0.645574  0.488367  0.484925  0.714517
# 342  0.016924  0.595805  0.917221  0.351070  0.483793
# 343  0.775888  0.106898  0.794564  0.347281  0.614387
#
# [344 rows x 5 columns]

# %%
newdf.loc[[1,2],:]
# Out:
#          0        1         2         3         4
# 1     Uday   Dipesh  0.341397  0.462687  0.792074
# 2  0.21743  0.32596  0.572147  0.600758  0.015973

# %%
newdf.loc[1,2]
# Out:
# 0.3413970644061217

# %%
newdf.loc[[1,2],[1,2]]
# Out:
#          1         2
# 1   Dipesh  0.341397
# 2  0.32596  0.572147

# %%
newdf.columns = list("ABCDE")

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0  0.392648     ROhan  0.226544  0.667087  0.961524
# 1      Uday    Dipesh  0.341397  0.462687  0.792074
# 2   0.21743   0.32596  0.572147  0.600758  0.015973
# 3  0.704062  0.103476  0.721498  0.828908  0.567209
# 4  0.992961  0.834203  0.128913  0.611308  0.837718

# %%
newdf.loc[0,'A'] = 'Atul'

# %%
newdf
# Out:
#             A         B         C         D         E
# 0        Atul     ROhan  0.226544  0.667087  0.961524
# 1        Uday    Dipesh  0.341397  0.462687  0.792074
# 2     0.21743   0.32596  0.572147  0.600758  0.015973
# 3    0.704062  0.103476  0.721498  0.828908  0.567209
# 4    0.992961  0.834203  0.128913  0.611308  0.837718
# ..        ...       ...       ...       ...       ...
# 339  0.444353  0.319412  0.829144  0.450701  0.249373
# 340   0.96952  0.180191  0.925243  0.054374  0.285382
# 341  0.651217  0.645574  0.488367  0.484925  0.714517
# 342  0.016924  0.595805  0.917221  0.351070  0.483793
# 343  0.775888  0.106898  0.794564  0.347281  0.614387
#
# [344 rows x 5 columns]

# %%
newdf.loc[0,0]  = 'Adiya'

# %%
newdf
# Out:
#             A         B         C         D         E      0
# 0        Atul     ROhan  0.226544  0.667087  0.961524  Adiya
# 1        Uday    Dipesh  0.341397  0.462687  0.792074    NaN
# 2     0.21743   0.32596  0.572147  0.600758  0.015973    NaN
# 3    0.704062  0.103476  0.721498  0.828908  0.567209    NaN
# 4    0.992961  0.834203  0.128913  0.611308  0.837718    NaN
# ..        ...       ...       ...       ...       ...    ...
# 339  0.444353  0.319412  0.829144  0.450701  0.249373    NaN
# 340   0.96952  0.180191  0.925243  0.054374  0.285382    NaN
# 341  0.651217  0.645574  0.488367  0.484925  0.714517    NaN
# 342  0.016924  0.595805  0.917221  0.351070  0.483793    NaN
# 343  0.775888  0.106898  0.794564  0.347281  0.614387    NaN
#
# [344 rows x 6 columns]

# %%
newdf = newdf.drop(0,axis=1)

# %%
newdf
# Out:
#             A         B         C         D         E
# 0        Atul     ROhan  0.226544  0.667087  0.961524
# 1        Uday    Dipesh  0.341397  0.462687  0.792074
# 2     0.21743   0.32596  0.572147  0.600758  0.015973
# 3    0.704062  0.103476  0.721498  0.828908  0.567209
# 4    0.992961  0.834203  0.128913  0.611308  0.837718
# ..        ...       ...       ...       ...       ...
# 339  0.444353  0.319412  0.829144  0.450701  0.249373
# 340   0.96952  0.180191  0.925243  0.054374  0.285382
# 341  0.651217  0.645574  0.488367  0.484925  0.714517
# 342  0.016924  0.595805  0.917221  0.351070  0.483793
# 343  0.775888  0.106898  0.794564  0.347281  0.614387
#
# [344 rows x 5 columns]

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0      Atul     ROhan  0.226544  0.667087  0.961524
# 1      Uday    Dipesh  0.341397  0.462687  0.792074
# 2   0.21743   0.32596  0.572147  0.600758  0.015973
# 3  0.704062  0.103476  0.721498  0.828908  0.567209
# 4  0.992961  0.834203  0.128913  0.611308  0.837718

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0      Atul     ROhan  0.226544  0.667087  0.961524
# 1      Uday    Dipesh  0.341397  0.462687  0.792074
# 2   0.21743   0.32596  0.572147  0.600758  0.015973
# 3  0.704062  0.103476  0.721498  0.828908  0.567209
# 4  0.992961  0.834203  0.128913  0.611308  0.837718

# %%
newdf.loc[[0,1],['A','B']]
# Out:
#       A       B
# 0  Atul   ROhan
# 1  Uday  Dipesh

# %%
newdf.loc[0,'B'] = 3

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0         4         3  0.226544  0.667087  0.961524
# 1         5        34  0.341397  0.462687  0.792074
# 2   0.21743   0.32596  0.572147  0.600758  0.015973
# 3  0.704062  0.103476  0.721498  0.828908  0.567209
# 4  0.992961  0.834203  0.128913  0.611308  0.837718

# %%
newdf.loc[(newdf['A']< 0.7) & (newdf['B'] > 0.5)]
# Out:
#             A         B         C         D         E
# 11   0.374902  0.712952  0.729490  0.242851  0.063420
# 14   0.183505  0.806336  0.455303  0.091067  0.300192
# 25   0.224435   0.72468  0.570817  0.119307  0.948292
# 29   0.294758  0.678772  0.396298  0.314324  0.096617
# 30   0.643927  0.896217  0.347398  0.579261  0.528687
# ..        ...       ...       ...       ...       ...
# 335  0.651927  0.882292  0.056950  0.301413  0.969550
# 337  0.062347  0.708112  0.476528  0.571073  0.290786
# 338  0.218695  0.598796  0.083130  0.248360  0.320020
# 341  0.651217  0.645574  0.488367  0.484925  0.714517
# 342  0.016924  0.595805  0.917221  0.351070  0.483793
#
# [120 rows x 5 columns]

# %%
data = {'col_1': [43,46,24],
        'col_2' : [523,75,34]}

# %%
daf = pd.DataFrame(data)

# %%
daf
# Out:
#    col_1  col_2
# 0     43    523
# 1     46     75
# 2     24     34

# %%
daf.describe
# Out:
# <bound method NDFrame.describe of    col_1  col_2
# 0     43    523
# 1     46     75
# 2     24     34>

# %%
daf.describe()
# Out:
#            col_1       col_2
# count   3.000000    3.000000
# mean   37.666667  210.666667
# std    11.930353  271.264324
# min    24.000000   34.000000
# 25%    33.500000   54.500000
# 50%    43.000000   75.000000
# 75%    44.500000  299.000000
# max    46.000000  523.000000

# %%
daf.mean()
# Out:
# col_1     37.666667
# col_2    210.666667
# dtype: float64

# %%
daf.head()
# Out:
#    col_1  col_2
# 0     43    523
# 1     46     75
# 2     24     34

# %%
daf.corr
# Out:
# <bound method DataFrame.corr of    col_1  col_2
# 0     43    523
# 1     46     75
# 2     24     34>

# %%
daf.count()
# Out:
# col_1    3
# col_2    3
# dtype: int64

# %%
daf.max()
# Out:
# col_1     46
# col_2    523
# dtype: int64

# %%
daf.min()
# Out:
# col_1    24
# col_2    34
# dtype: int64

# %%
daf.meadian()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11528\2267114672.py in ?()
# ----> 1 daf.meadian()
#
# c:\Users\Rohan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'meadian'

# %%
daf.median()
# Out:
# col_1    43.0
# col_2    75.0
# dtype: float64

# %%
daf.head()
# Out:
#    col_1  col_2
# 0     43    523
# 1     46     75
# 2     24     34

# %%
daf.median(axis=0)
# Out:
# col_1    43.0
# col_2    75.0
# dtype: float64

# %%
daf.median(axis=1)
# Out:
# 0    283.0
# 1     60.5
# 2     29.0
# dtype: float64

# %%
daf.std()
# Out:
# col_1     11.930353
# col_2    271.264324
# dtype: float64
